# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# show all columns on pandas dataframes
pd.set_option('display.max_columns', None)

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
# library(ggplot2)
#
# # read data from CSV file
# df <- read.csv("Expected.csv")
#
# # create bar chart
# ggplot(data = df, aes(x = Response, y = Pct_MLM)) +
#   geom_bar(stat = "identity") +
#   labs(title = "Most MLM participants said their company did not accurately represent their chances at financial success", x = "Category", y = "Value")

# %%
# %%R
#
# library(RColorBrewer)
# mydata <- read.csv("Expected.csv")
# #install.packages("treemap")
# library(treemap)
#
#
#
# pdf('Expected.pdf');treemap(mydata, index=c("Response"), vSize="MLM",
#
#     type="index",
#     palette= "Reds",
#     title="My Treemap",
#     fontcolor.labels=c("black"),
#     fontsize.title=12,)
